# %%
import pandas as pd

# %%
df = pd.read_csv('leicht_nachricht.csv')

# %%
df
# Out:
#       Line_ID  day    month  year     category  \
# 0           0   14      Mai  2021       Kultur
# 1           1   14      Mai  2021       Kultur
# 2           2   14      Mai  2021       Kultur
# 3           3    7      Mai  2021       Kultur
# 4           4    7      Mai  2021       Kultur
# ...       ...  ...      ...   ...          ...
# 5819     5819   16  Februar  2013  Nachrichten
# 5820     5820   16  Februar  2013  Nachrichten
# 5821     5821   16  Februar  2013  Nachrichten
# 5822     5822   16  Februar  2013  Nachrichten
# 5823     5823    9  Februar  2013  Nachrichten
#
#                                    article  \
# 0                      \nFernseh-Preise \n
# 1              \nFilm-Festival in Berlin\n
# 2                   \nPreise für Schulen\n
# 3                   \nParty in Liverpool\n
# 4        \nDeutschland gibt Kunst zurück\n
# ...                                    ...
# 5819          \nNeue Bildungs-Ministerin\n
# ...

# %%
df_normal = pd.read_csv('normal_nachricht.csv')

# %%
df_normal
# Out:
#       Line_ID   day  month    year category  \
# 0           0  29.0    3.0  2021.0  Politik
# 1           1  24.0    2.0  2021.0  Politik
# 2           2  15.0    2.0  2021.0  Politik
# 3           3  12.0    5.0  2021.0  Politik
# 4           4   4.0    3.0  2021.0  Politik
# ...       ...   ...    ...     ...      ...
# 6000     6000  16.0    1.0  2021.0   Kultur
# 6001     6001  12.0    3.0  2021.0   Kultur
# 6002     6002   NaN    NaN     NaN      NaN
# 6003     6003   NaN    NaN     NaN      NaN
# 6004     6004   NaN    NaN     NaN      NaN
#
#                                                 article  \
# 0     Wie Merkel ohne die Länder ihre Coronapolitik ...
# 1         Spahn hält Inzidenz von null für unerreichbar
# 2            Linkenchef Riexinger unterstützt Hofreiter
# 3     Jens Spahn und RKI-Chef Lothar Wieler zur aktu...
# 4                                                \n\n\n
# ...                                                 ...
# ...

# %%
politik = pd.read_csv('Politik.csv')
sport = pd.read_csv('Sport.csv')
kultur = pd.read_csv('Kultur.csv')

# %%
kultur[1540:]
# Out:
#       Line_ID  day  month    year category  \
# 1540     1540  9.0    3.0  2021.0   Kultur
# 1541     1541  NaN    NaN     NaN      NaN
# 1542     1542  NaN    NaN     NaN      NaN
# 1543     1543  NaN    NaN     NaN      NaN
# 1544     1544  NaN    NaN     NaN      NaN
# ...       ...  ...    ...     ...      ...
# 1995     1995  NaN    NaN     NaN      NaN
# 1996     1996  NaN    NaN     NaN      NaN
# 1997     1997  NaN    NaN     NaN      NaN
# 1998     1998  NaN    NaN     NaN      NaN
# 1999     1999  NaN    NaN     NaN      NaN
#
#                                                 article  \
# 1540              Die deutsche Erinnerungsüberlegenheit
# 1541                   How to Sell Tatort Online (Fast)
# 1542                 Neues Album erst nach der Pandemie
# 1543                                             \n\n\n
# 1544                                Die Legende ist tot
# ...                                                 ...
# ...
